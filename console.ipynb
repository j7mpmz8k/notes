# %%
# custom command line arguments
import sys
def main():
    for i, arg in enumerate(sys.argv):
        if i != 0: print(arg)
main()

# run: `python program.py custom-arg ---hello`
# output: `custom-arg ---hello`
# Out:
# /home/crostini/.pyenv/versions/3.14.2t/lib/python3.14t/site-packages/ipykernel_launcher.py
# --f=/run/user/1000/jupyter/runtime/kernel-v398ed181bad6b1b578e7a5f147c2a88c3095c6e05.json

# %%
#To ask user in console to input information and set input to a variable
answer = input("enter prompt here then press enter: ") #"answer" = a variable
#Out: enter prompt here then press enter:

# %%
print("hello", "world")# two arguments
print("hellow"+" world")# one argument
